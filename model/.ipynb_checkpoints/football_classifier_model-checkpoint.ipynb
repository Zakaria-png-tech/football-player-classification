# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
img = cv2.imread('test_images/messi.jpg')

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray,cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray,1.3,5)
faces
# Out:
# array([[99, 28, 74, 74]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (99, 28, 74, 74)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h,x:x+w]
    roi_color = face_img[y:y+h,x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
plt.figure()
plt.imshow(face_img,cmap='gray')
plt.show()

# %%
plt.imshow(roi_color)

# %%
from pathlib import Path
def get_cropped_img(image_path):
    image_path = Path(image_path)
    img = cv2.imread(str(image_path))
    if img is None:
        print('Could not read image: ',image_path)
        return None 
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray,1.3,5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h,x:x+w]
        roi_color = img[y:y+h,x:x+w]
        '''eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color'''
        return roi_color

# %%
img_original = cv2.imread('test_images/messi.jpg')
plt.imshow(img_original)

# %%
img_cropped = get_cropped_img('test_images/messi.jpg')
plt.imshow(img_cropped)

# %%
img_not_clear = cv2.imread('test_images/Lionel Messi.jpg')
plt.imshow(img_not_clear)

# %%
img_cropped_no_eyes = get_cropped_img('test_images/Lionel Messi.jpg')
img_cropped_no_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os 
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cristiano ronaldo',
#  './dataset/lionel messi',
#  './dataset/maradona',
#  './dataset/neymar jr',
#  './dataset/pele']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
import string

def safe_rename(folder):
    folder_name = os.path.basename(folder).replace(" ", "_").lower()
    valid_chars = f"-_.() {string.ascii_letters}{string.digits}"
    
    files = os.listdir(folder)
    counter = 1
    for file in files:
        old_path = os.path.join(folder, file)
        if not os.path.isfile(old_path):
            continue
        # get extension
        ext = os.path.splitext(file)[1]
        # create simple name
        new_name = f"{folder_name}_{counter}{ext}"
        new_name = ''.join(c for c in new_name if c in valid_chars)
        new_path = os.path.join(folder, new_name)
        # ensure unique
        while os.path.exists(new_path):
            counter += 1
            new_name = f"{folder_name}_{counter}{ext}"
            new_name = ''.join(c for c in new_name if c in valid_chars)
            new_path = os.path.join(folder, new_name)
        os.rename(old_path, new_path)
        counter += 1
    print(f"Renamed images in folder: {folder_name}")

# Apply to all folders
for folder in img_dirs:
    safe_rename(folder)
# Out:
# Renamed images in folder: cristiano_ronaldo
# Renamed images in folder: cropped
# Renamed images in folder: lionel_messi
# Renamed images in folder: maradona
# Renamed images in folder: neymar_jr
# Renamed images in folder: pele

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count=1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)

    celebrity_file_names_dict[celebrity_name]=[]
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_img(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generate cropped images in a folder : ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + '.png'
            cropped_file_path = cropped_folder + '/' +cropped_file_name

            cv2.imwrite(cropped_file_path,roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count+=1
# Out:
# cristiano ronaldo
# Generate cropped images in a folder :  ./dataset/cropped/cristiano ronaldo
# lionel messi
# Generate cropped images in a folder :  ./dataset/cropped/lionel messi
# Could not read image:  dataset\lionel messi\lionel_messi_610.htm
# Could not read image:  dataset\lionel messi\lionel_messi_612.htm
# Could not read image:  dataset\lionel messi\lionel_messi_613.htm
# Could not read image:  dataset\lionel messi\lionel_messi_614.htm
# Could not read image:  dataset\lionel messi\lionel_messi_615.htm
# maradona
# Generate cropped images in a folder :  ./dataset/cropped/maradona
# Could not read image:  dataset\maradona\maradona_29.htm
# neymar jr
# Generate cropped images in a folder :  ./dataset/cropped/neymar jr
# Could not read image:  dataset\neymar jr\neymar_jr_236.htm
# Could not read image:  dataset\neymar jr\neymar_jr_237.htm
# pele
# Generate cropped images in a folder :  ./dataset/cropped/pele

# %%
import pywt

def w2d(img,mode='haar',level=1):
    imArray = img
    #convert to grayscale
    imArray = cv2.cvtColor(imArray,cv2.COLOR_BGR2GRAY)
    #convert to float 
    imArray = np.float32(imArray)
    imArray /= 255
    #compute coefficients
    coeffs=pywt.wavedec2(imArray,mode,level=level)
    #process coefficients
    coeffs_H = list(coeffs)
    coeffs_H[0] *= 0
    #reconstruction
    imArray_H = pywt.waverec2(coeffs_H,mode)
    imArray_H *= 255
    imArray_H = np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(img_cropped,'db1',5)
plt.imshow(im_har,cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'cristiano ronaldo': ['./dataset/cropped/cristiano ronaldo/cristiano ronaldo1.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo2.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo3.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo4.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo5.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo6.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo7.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo8.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo9.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo10.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo11.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo12.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo13.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo14.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo15.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo16.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo17.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo18.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo19.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo20.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo21.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo22.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo23.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo24.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo25.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo26.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo27.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo28.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo29.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo30.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo31.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo32.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo33.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo34.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo35.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo36.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo37.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo38.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo39.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo40.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo41.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo42.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo43.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo44.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo45.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo46.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo47.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo48.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo49.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo50.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo51.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo52.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo53.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo54.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo55.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo56.png',
#   './dataset/cropped/cristiano ronaldo/cristiano ronaldo57.png'],
#  'cropped': [],
#  'lionel messi': ['./dataset/cropped/lionel messi/lionel messi1.png',
#   './dataset/cropped/lionel messi/lionel messi2.png',
#   './dataset/cropped/lionel messi/lionel messi3.png',
#   './dataset/cropped/lionel messi/lionel messi4.png',
#   './dataset/cropped/lionel messi/lionel messi5.png',
#   './dataset/cropped/lionel messi/lionel messi6.png',
#   './dataset/cropped/lionel messi/lionel messi7.png',
#   './dataset/cropped/lionel messi/lionel messi8.png',
#   './dataset/cropped/lionel messi/lionel messi9.png',
#   './dataset/cropped/lionel messi/lionel messi10.png',
#   './dataset/cropped/lionel messi/lionel messi11.png',
#   './dataset/cropped/lionel messi/lionel messi12.png',
#   './dataset/cropped/lionel messi/lionel messi13.png',
#   './dataset/cropped/lionel messi/lionel messi14.png',
#   './dataset/cropped/lionel messi/lionel messi15.png',
#   './dataset/cropped/lionel messi/lionel messi16.png',
#   './dataset/cropped/lionel messi/lionel messi17.png',
#   './dataset/cropped/lionel messi/lionel messi18.png',
#   './dataset/cropped/lionel messi/lionel messi19.png',
#   './dataset/cropped/lionel messi/lionel messi20.png',
#   './dataset/cropped/lionel messi/lionel messi21.png',
#   './dataset/cropped/lionel messi/lionel messi22.png',
#   './dataset/cropped/lionel messi/lionel messi23.png',
#   './dataset/cropped/lionel messi/lionel messi24.png',
#   './dataset/cropped/lionel messi/lionel messi25.png',
#   './dataset/cropped/lionel messi/lionel messi26.png',
#   './dataset/cropped/lionel messi/lionel messi27.png',
#   './dataset/cropped/lionel messi/lionel messi28.png',
#   './dataset/cropped/lionel messi/lionel messi29.png',
#   './dataset/cropped/lionel messi/lionel messi30.png',
#   './dataset/cropped/lionel messi/lionel messi31.png',
#   './dataset/cropped/lionel messi/lionel messi32.png',
#   './dataset/cropped/lionel messi/lionel messi33.png',
#   './dataset/cropped/lionel messi/lionel messi34.png',
#   './dataset/cropped/lionel messi/lionel messi35.png',
#   './dataset/cropped/lionel messi/lionel messi36.png',
#   './dataset/cropped/lionel messi/lionel messi37.png',
#   './dataset/cropped/lionel messi/lionel messi38.png',
#   './dataset/cropped/lionel messi/lionel messi39.png',
#   './dataset/cropped/lionel messi/lionel messi40.png',
#   './dataset/cropped/lionel messi/lionel messi41.png',
#   './dataset/cropped/lionel messi/lionel messi42.png',
#   './dataset/cropped/lionel messi/lionel messi43.png',
#   './dataset/cropped/lionel messi/lionel messi44.png',
#   './dataset/cropped/lionel messi/lionel messi45.png',
#   './dataset/cropped/lionel messi/lionel messi46.png',
#   './dataset/cropped/lionel messi/lionel messi47.png',
#   './dataset/cropped/lionel messi/lionel messi48.png',
#   './dataset/cropped/lionel messi/lionel messi49.png',
#   './dataset/cropped/lionel messi/lionel messi50.png',
#   './dataset/cropped/lionel messi/lionel messi51.png',
#   './dataset/cropped/lionel messi/lionel messi52.png',
#   './dataset/cropped/lionel messi/lionel messi53.png',
#   './dataset/cropped/lionel messi/lionel messi54.png',
#   './dataset/cropped/lionel messi/lionel messi55.png',
#   './dataset/cropped/lionel messi/lionel messi56.png',
#   './dataset/cropped/lionel messi/lionel messi57.png',
#   './dataset/cropped/lionel messi/lionel messi58.png',
#   './dataset/cropped/lionel messi/lionel messi59.png',
#   './dataset/cropped/lionel messi/lionel messi60.png',
#   './dataset/cropped/lionel messi/lionel messi61.png',
#   './dataset/cropped/lionel messi/lionel messi62.png',
#   './dataset/cropped/lionel messi/lionel messi63.png',
#   './dataset/cropped/lionel messi/lionel messi64.png',
#   './dataset/cropped/lionel messi/lionel messi65.png',
#   './dataset/cropped/lionel messi/lionel messi66.png',
#   './dataset/cropped/lionel messi/lionel messi67.png',
#   './dataset/cropped/lionel messi/lionel messi68.png',
#   './dataset/cropped/lionel messi/lionel messi69.png',
#   './dataset/cropped/lionel messi/lionel messi70.png',
#   './dataset/cropped/lionel messi/lionel messi71.png',
#   './dataset/cropped/lionel messi/lionel messi72.png',
#   './dataset/cropped/lionel messi/lionel messi73.png',
#   './dataset/cropped/lionel messi/lionel messi74.png',
#   './dataset/cropped/lionel messi/lionel messi75.png',
#   './dataset/cropped/lionel messi/lionel messi76.png',
#   './dataset/cropped/lionel messi/lionel messi77.png',
#   './dataset/cropped/lionel messi/lionel messi78.png',
#   './dataset/cropped/lionel messi/lionel messi79.png',
#   './dataset/cropped/lionel messi/lionel messi80.png',
#   './dataset/cropped/lionel messi/lionel messi81.png',
#   './dataset/cropped/lionel messi/lionel messi82.png',
#   './dataset/cropped/lionel messi/lionel messi83.png',
#   './dataset/cropped/lionel messi/lionel messi84.png',
#   './dataset/cropped/lionel messi/lionel messi85.png',
#   './dataset/cropped/lionel messi/lionel messi86.png',
#   './dataset/cropped/lionel messi/lionel messi87.png',
#   './dataset/cropped/lionel messi/lionel messi88.png',
#   './dataset/cropped/lionel messi/lionel messi89.png',
#   './dataset/cropped/lionel messi/lionel messi90.png',
#   './dataset/cropped/lionel messi/lionel messi91.png',
#   './dataset/cropped/lionel messi/lionel messi92.png',
#   './dataset/cropped/lionel messi/lionel messi93.png',
#   './dataset/cropped/lionel messi/lionel messi94.png',
#   './dataset/cropped/lionel messi/lionel messi95.png',
#   './dataset/cropped/lionel messi/lionel messi96.png',
#   './dataset/cropped/lionel messi/lionel messi97.png',
#   './dataset/cropped/lionel messi/lionel messi98.png',
#   './dataset/cropped/lionel messi/lionel messi99.png',
#   './dataset/cropped/lionel messi/lionel messi100.png',
#   './dataset/cropped/lionel messi/lionel messi101.png',
#   './dataset/cropped/lionel messi/lionel messi102.png',
#   './dataset/cropped/lionel messi/lionel messi103.png',
#   './dataset/cropped/lionel messi/lionel messi104.png',
#   './dataset/cropped/lionel messi/lionel messi105.png',
#   './dataset/cropped/lionel messi/lionel messi106.png',
#   './dataset/cropped/lionel messi/lionel messi107.png',
#   './dataset/cropped/lionel messi/lionel messi108.png',
#   './dataset/cropped/lionel messi/lionel messi109.png',
#   './dataset/cropped/lionel messi/lionel messi110.png',
#   './dataset/cropped/lionel messi/lionel messi111.png',
#   './dataset/cropped/lionel messi/lionel messi112.png',
#   './dataset/cropped/lionel messi/lionel messi113.png',
#   './dataset/cropped/lionel messi/lionel messi114.png',
#   './dataset/cropped/lionel messi/lionel messi115.png',
#   './dataset/cropped/lionel messi/lionel messi116.png',
#   './dataset/cropped/lionel messi/lionel messi117.png',
#   './dataset/cropped/lionel messi/lionel messi118.png',
#   './dataset/cropped/lionel messi/lionel messi119.png',
#   './dataset/cropped/lionel messi/lionel messi120.png',
#   './dataset/cropped/lionel messi/lionel messi121.png',
#   './dataset/cropped/lionel messi/lionel messi122.png',
#   './dataset/cropped/lionel messi/lionel messi123.png',
#   './dataset/cropped/lionel messi/lionel messi124.png',
#   './dataset/cropped/lionel messi/lionel messi125.png',
#   './dataset/cropped/lionel messi/lionel messi126.png',
#   './dataset/cropped/lionel messi/lionel messi127.png',
#   './dataset/cropped/lionel messi/lionel messi128.png',
#   './dataset/cropped/lionel messi/lionel messi129.png',
#   './dataset/cropped/lionel messi/lionel messi130.png',
#   './dataset/cropped/lionel messi/lionel messi131.png',
#   './dataset/cropped/lionel messi/lionel messi132.png',
#   './dataset/cropped/lionel messi/lionel messi133.png',
#   './dataset/cropped/lionel messi/lionel messi134.png',
#   './dataset/cropped/lionel messi/lionel messi135.png',
#   './dataset/cropped/lionel messi/lionel messi136.png',
#   './dataset/cropped/lionel messi/lionel messi137.png',
#   './dataset/cropped/lionel messi/lionel messi138.png',
#   './dataset/cropped/lionel messi/lionel messi139.png',
#   './dataset/cropped/lionel messi/lionel messi140.png',
#   './dataset/cropped/lionel messi/lionel messi141.png',
#   './dataset/cropped/lionel messi/lionel messi142.png',
#   './dataset/cropped/lionel messi/lionel messi143.png',
#   './dataset/cropped/lionel messi/lionel messi144.png',
#   './dataset/cropped/lionel messi/lionel messi145.png',
#   './dataset/cropped/lionel messi/lionel messi146.png',
#   './dataset/cropped/lionel messi/lionel messi147.png',
#   './dataset/cropped/lionel messi/lionel messi148.png',
#   './dataset/cropped/lionel messi/lionel messi149.png',
#   './dataset/cropped/lionel messi/lionel messi150.png',
#   './dataset/cropped/lionel messi/lionel messi151.png',
#   './dataset/cropped/lionel messi/lionel messi152.png',
#   './dataset/cropped/lionel messi/lionel messi153.png',
#   './dataset/cropped/lionel messi/lionel messi154.png',
#   './dataset/cropped/lionel messi/lionel messi155.png',
#   './dataset/cropped/lionel messi/lionel messi156.png',
#   './dataset/cropped/lionel messi/lionel messi157.png',
#   './dataset/cropped/lionel messi/lionel messi158.png',
#   './dataset/cropped/lionel messi/lionel messi159.png',
#   './dataset/cropped/lionel messi/lionel messi160.png',
#   './dataset/cropped/lionel messi/lionel messi161.png',
#   './dataset/cropped/lionel messi/lionel messi162.png',
#   './dataset/cropped/lionel messi/lionel messi163.png',
#   './dataset/cropped/lionel messi/lionel messi164.png',
#   './dataset/cropped/lionel messi/lionel messi165.png',
#   './dataset/cropped/lionel messi/lionel messi166.png',
#   './dataset/cropped/lionel messi/lionel messi167.png',
#   './dataset/cropped/lionel messi/lionel messi168.png',
#   './dataset/cropped/lionel messi/lionel messi169.png',
#   './dataset/cropped/lionel messi/lionel messi170.png',
#   './dataset/cropped/lionel messi/lionel messi171.png',
#   './dataset/cropped/lionel messi/lionel messi172.png',
#   './dataset/cropped/lionel messi/lionel messi173.png',
#   './dataset/cropped/lionel messi/lionel messi174.png',
#   './dataset/cropped/lionel messi/lionel messi175.png',
#   './dataset/cropped/lionel messi/lionel messi176.png',
#   './dataset/cropped/lionel messi/lionel messi177.png',
#   './dataset/cropped/lionel messi/lionel messi178.png',
#   './dataset/cropped/lionel messi/lionel messi179.png',
#   './dataset/cropped/lionel messi/lionel messi180.png',
#   './dataset/cropped/lionel messi/lionel messi181.png',
#   './dataset/cropped/lionel messi/lionel messi182.png',
#   './dataset/cropped/lionel messi/lionel messi183.png',
#   './dataset/cropped/lionel messi/lionel messi184.png',
#   './dataset/cropped/lionel messi/lionel messi185.png',
#   './dataset/cropped/lionel messi/lionel messi186.png',
#   './dataset/cropped/lionel messi/lionel messi187.png',
#   './dataset/cropped/lionel messi/lionel messi188.png',
#   './dataset/cropped/lionel messi/lionel messi189.png',
#   './dataset/cropped/lionel messi/lionel messi190.png',
#   './dataset/cropped/lionel messi/lionel messi191.png',
#   './dataset/cropped/lionel messi/lionel messi192.png',
#   './dataset/cropped/lionel messi/lionel messi193.png',
#   './dataset/cropped/lionel messi/lionel messi194.png',
#   './dataset/cropped/lionel messi/lionel messi195.png',
#   './dataset/cropped/lionel messi/lionel messi196.png',
#   './dataset/cropped/lionel messi/lionel messi197.png',
#   './dataset/cropped/lionel messi/lionel messi198.png',
#   './dataset/cropped/lionel messi/lionel messi199.png',
#   './dataset/cropped/lionel messi/lionel messi200.png',
#   './dataset/cropped/lionel messi/lionel messi201.png',
#   './dataset/cropped/lionel messi/lionel messi202.png',
#   './dataset/cropped/lionel messi/lionel messi203.png',
#   './dataset/cropped/lionel messi/lionel messi204.png',
#   './dataset/cropped/lionel messi/lionel messi205.png',
#   './dataset/cropped/lionel messi/lionel messi206.png',
#   './dataset/cropped/lionel messi/lionel messi207.png',
#   './dataset/cropped/lionel messi/lionel messi208.png',
#   './dataset/cropped/lionel messi/lionel messi209.png',
#   './dataset/cropped/lionel messi/lionel messi210.png',
#   './dataset/cropped/lionel messi/lionel messi211.png',
#   './dataset/cropped/lionel messi/lionel messi212.png',
#   './dataset/cropped/lionel messi/lionel messi213.png',
#   './dataset/cropped/lionel messi/lionel messi214.png'],
#  'maradona': ['./dataset/cropped/maradona/maradona1.png',
#   './dataset/cropped/maradona/maradona2.png',
#   './dataset/cropped/maradona/maradona3.png',
#   './dataset/cropped/maradona/maradona4.png',
#   './dataset/cropped/maradona/maradona5.png',
#   './dataset/cropped/maradona/maradona6.png',
#   './dataset/cropped/maradona/maradona7.png',
#   './dataset/cropped/maradona/maradona8.png',
#   './dataset/cropped/maradona/maradona9.png',
#   './dataset/cropped/maradona/maradona10.png',
#   './dataset/cropped/maradona/maradona11.png',
#   './dataset/cropped/maradona/maradona12.png',
#   './dataset/cropped/maradona/maradona13.png',
#   './dataset/cropped/maradona/maradona14.png',
#   './dataset/cropped/maradona/maradona15.png',
#   './dataset/cropped/maradona/maradona16.png',
#   './dataset/cropped/maradona/maradona17.png',
#   './dataset/cropped/maradona/maradona18.png',
#   './dataset/cropped/maradona/maradona19.png',
#   './dataset/cropped/maradona/maradona20.png',
#   './dataset/cropped/maradona/maradona21.png',
#   './dataset/cropped/maradona/maradona22.png',
#   './dataset/cropped/maradona/maradona23.png',
#   './dataset/cropped/maradona/maradona24.png',
#   './dataset/cropped/maradona/maradona25.png',
#   './dataset/cropped/maradona/maradona26.png',
#   './dataset/cropped/maradona/maradona27.png',
#   './dataset/cropped/maradona/maradona28.png',
#   './dataset/cropped/maradona/maradona29.png',
#   './dataset/cropped/maradona/maradona30.png',
#   './dataset/cropped/maradona/maradona31.png',
#   './dataset/cropped/maradona/maradona32.png',
#   './dataset/cropped/maradona/maradona33.png',
#   './dataset/cropped/maradona/maradona34.png',
#   './dataset/cropped/maradona/maradona35.png',
#   './dataset/cropped/maradona/maradona36.png',
#   './dataset/cropped/maradona/maradona37.png',
#   './dataset/cropped/maradona/maradona38.png',
#   './dataset/cropped/maradona/maradona39.png',
#   './dataset/cropped/maradona/maradona40.png',
#   './dataset/cropped/maradona/maradona41.png',
#   './dataset/cropped/maradona/maradona42.png',
#   './dataset/cropped/maradona/maradona43.png',
#   './dataset/cropped/maradona/maradona44.png',
#   './dataset/cropped/maradona/maradona45.png',
#   './dataset/cropped/maradona/maradona46.png',
#   './dataset/cropped/maradona/maradona47.png',
#   './dataset/cropped/maradona/maradona48.png',
#   './dataset/cropped/maradona/maradona49.png',
#   './dataset/cropped/maradona/maradona50.png',
#   './dataset/cropped/maradona/maradona51.png',
#   './dataset/cropped/maradona/maradona52.png',
#   './dataset/cropped/maradona/maradona53.png',
#   './dataset/cropped/maradona/maradona54.png'],
#  'neymar jr': ['./dataset/cropped/neymar jr/neymar jr1.png',
#   './dataset/cropped/neymar jr/neymar jr2.png',
#   './dataset/cropped/neymar jr/neymar jr3.png',
#   './dataset/cropped/neymar jr/neymar jr4.png',
#   './dataset/cropped/neymar jr/neymar jr5.png',
#   './dataset/cropped/neymar jr/neymar jr6.png',
#   './dataset/cropped/neymar jr/neymar jr7.png',
#   './dataset/cropped/neymar jr/neymar jr8.png',
#   './dataset/cropped/neymar jr/neymar jr9.png',
#   './dataset/cropped/neymar jr/neymar jr10.png',
#   './dataset/cropped/neymar jr/neymar jr11.png',
#   './dataset/cropped/neymar jr/neymar jr12.png',
#   './dataset/cropped/neymar jr/neymar jr13.png',
#   './dataset/cropped/neymar jr/neymar jr14.png',
#   './dataset/cropped/neymar jr/neymar jr15.png',
#   './dataset/cropped/neymar jr/neymar jr16.png',
#   './dataset/cropped/neymar jr/neymar jr17.png',
#   './dataset/cropped/neymar jr/neymar jr18.png',
#   './dataset/cropped/neymar jr/neymar jr19.png',
#   './dataset/cropped/neymar jr/neymar jr20.png',
#   './dataset/cropped/neymar jr/neymar jr21.png',
#   './dataset/cropped/neymar jr/neymar jr22.png',
#   './dataset/cropped/neymar jr/neymar jr23.png',
#   './dataset/cropped/neymar jr/neymar jr24.png',
#   './dataset/cropped/neymar jr/neymar jr25.png',
#   './dataset/cropped/neymar jr/neymar jr26.png',
#   './dataset/cropped/neymar jr/neymar jr27.png',
#   './dataset/cropped/neymar jr/neymar jr28.png',
#   './dataset/cropped/neymar jr/neymar jr29.png',
#   './dataset/cropped/neymar jr/neymar jr30.png',
#   './dataset/cropped/neymar jr/neymar jr31.png',
#   './dataset/cropped/neymar jr/neymar jr32.png',
#   './dataset/cropped/neymar jr/neymar jr33.png',
#   './dataset/cropped/neymar jr/neymar jr34.png',
#   './dataset/cropped/neymar jr/neymar jr35.png',
#   './dataset/cropped/neymar jr/neymar jr36.png',
#   './dataset/cropped/neymar jr/neymar jr37.png',
#   './dataset/cropped/neymar jr/neymar jr38.png',
#   './dataset/cropped/neymar jr/neymar jr39.png',
#   './dataset/cropped/neymar jr/neymar jr40.png',
#   './dataset/cropped/neymar jr/neymar jr41.png',
#   './dataset/cropped/neymar jr/neymar jr42.png',
#   './dataset/cropped/neymar jr/neymar jr43.png',
#   './dataset/cropped/neymar jr/neymar jr44.png',
#   './dataset/cropped/neymar jr/neymar jr45.png',
#   './dataset/cropped/neymar jr/neymar jr46.png',
#   './dataset/cropped/neymar jr/neymar jr47.png',
#   './dataset/cropped/neymar jr/neymar jr48.png',
#   './dataset/cropped/neymar jr/neymar jr49.png',
#   './dataset/cropped/neymar jr/neymar jr50.png',
#   './dataset/cropped/neymar jr/neymar jr51.png',
#   './dataset/cropped/neymar jr/neymar jr52.png',
#   './dataset/cropped/neymar jr/neymar jr53.png',
#   './dataset/cropped/neymar jr/neymar jr54.png',
#   './dataset/cropped/neymar jr/neymar jr55.png',
#   './dataset/cropped/neymar jr/neymar jr56.png',
#   './dataset/cropped/neymar jr/neymar jr57.png',
#   './dataset/cropped/neymar jr/neymar jr58.png',
#   './dataset/cropped/neymar jr/neymar jr59.png',
#   './dataset/cropped/neymar jr/neymar jr60.png',
#   './dataset/cropped/neymar jr/neymar jr61.png',
#   './dataset/cropped/neymar jr/neymar jr62.png',
#   './dataset/cropped/neymar jr/neymar jr63.png',
#   './dataset/cropped/neymar jr/neymar jr64.png',
#   './dataset/cropped/neymar jr/neymar jr65.png',
#   './dataset/cropped/neymar jr/neymar jr66.png',
#   './dataset/cropped/neymar jr/neymar jr67.png',
#   './dataset/cropped/neymar jr/neymar jr68.png',
#   './dataset/cropped/neymar jr/neymar jr69.png',
#   './dataset/cropped/neymar jr/neymar jr70.png'],
#  'pele': ['./dataset/cropped/pele/pele1.png',
#   './dataset/cropped/pele/pele2.png',
#   './dataset/cropped/pele/pele3.png',
#   './dataset/cropped/pele/pele4.png',
#   './dataset/cropped/pele/pele5.png',
#   './dataset/cropped/pele/pele6.png',
#   './dataset/cropped/pele/pele7.png',
#   './dataset/cropped/pele/pele8.png',
#   './dataset/cropped/pele/pele9.png',
#   './dataset/cropped/pele/pele10.png',
#   './dataset/cropped/pele/pele11.png',
#   './dataset/cropped/pele/pele12.png',
#   './dataset/cropped/pele/pele13.png',
#   './dataset/cropped/pele/pele14.png',
#   './dataset/cropped/pele/pele15.png',
#   './dataset/cropped/pele/pele16.png',
#   './dataset/cropped/pele/pele17.png',
#   './dataset/cropped/pele/pele18.png',
#   './dataset/cropped/pele/pele19.png',
#   './dataset/cropped/pele/pele20.png',
#   './dataset/cropped/pele/pele21.png',
#   './dataset/cropped/pele/pele22.png',
#   './dataset/cropped/pele/pele23.png',
#   './dataset/cropped/pele/pele24.png',
#   './dataset/cropped/pele/pele25.png',
#   './dataset/cropped/pele/pele26.png',
#   './dataset/cropped/pele/pele27.png',
#   './dataset/cropped/pele/pele28.png',
#   './dataset/cropped/pele/pele29.png',
#   './dataset/cropped/pele/pele30.png',
#   './dataset/cropped/pele/pele31.png',
#   './dataset/cropped/pele/pele32.png',
#   './dataset/cropped/pele/pele33.png',
#   './dataset/cropped/pele/pele34.png',
#   './dataset/cropped/pele/pele35.png',
#   './dataset/cropped/pele/pele36.png',
#   './dataset/cropped/pele/pele37.png',
#   './dataset/cropped/pele/pele38.png',
#   './dataset/cropped/pele/pele39.png',
#   './dataset/cropped/pele/pele40.png',
#   './dataset/cropped/pele/pele41.png',
#   './dataset/cropped/pele/pele42.png',
#   './dataset/cropped/pele/pele43.png',
#   './dataset/cropped/pele/pele44.png',
#   './dataset/cropped/pele/pele45.png',
#   './dataset/cropped/pele/pele46.png',
#   './dataset/cropped/pele/pele47.png',
#   './dataset/cropped/pele/pele48.png',
#   './dataset/cropped/pele/pele49.png',
#   './dataset/cropped/pele/pele50.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'cristiano ronaldo': 0,
#  'lionel messi': 1,
#  'maradona': 2,
#  'neymar jr': 3,
#  'pele': 4}

# %%
X,y = [],[]
for celebrity_name,training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img,(32,32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har,(32,32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\pywt\_multilevel.py:43: UserWarning: Level value of 5 is too high: all coefficients will experience boundary effects.
#   warnings.warn(

# %%
len(X[0])
# Out:
# 4096

# %%
len(X)
# Out:
# 445

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (445, 4096)

# %% [markdown]
# # Model Training

# %%
from sklearn.svm import SVC 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

pipe = Pipeline([('scaler',StandardScaler()),('svc',SVC(kernel='rbf',C=10))])
pipe.fit(X_train,y_train)
pipe.score(X_test,y_test)
# Out:
# 0.6875

# %%
print(classification_report(y_test,pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.42      0.59        19
#            1       0.60      0.93      0.73        45
#            2       0.85      0.79      0.81        14
#            3       0.64      0.56      0.60        16
#            4       1.00      0.39      0.56        18
#
#     accuracy                           0.69       112
#    macro avg       0.82      0.62      0.66       112
# weighted avg       0.77      0.69      0.67       112

# %% [markdown]
# # Fine tuning

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params': {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params': {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression': {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(),mp['model'])
    clf = GridSearchCV(pipe,mp['params'],cv=5,return_train_score=False)
    clf.fit(X_train,y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.792809
# 1        random_forest    0.615739
# 2  logistic_regression    0.792899
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7678571428571429

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5267857142857143

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7678571428571429

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
plt.figure(figsize = (10,7))
sns.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# ### **Save model**

# %%
import joblib
joblib.dump(best_clf,'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %% [markdown]
# ### **Save class dictionary**

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
